# %% [markdown]
# #### Imports

# %%
import sys, os
import scanpy as sc

from pathlib import Path
sys.path.insert(0, str(Path("../..").resolve()))
from src.config import ANALYSIS_DIR

# %% [markdown]
# #### Load data

# %%
d4_lapa = sc.read_h5ad(ANALYSIS_DIR / "d4_lapa_manual_labels.h5ad")

# %%
#### Define a fixed colour palette
#### This can also be imported from utils.py in src

celltype_palette = {
    "ISCs": "#7f7f7f",
    "PCs": "#1ce6ff",
    "Secretory PCs": "#e31a1c",
    "Secretory progenitor cells": "#e31a1c",
    "Proliferating Progenitor cells": "#ff4a46",
    "Proliferating progenitor cells": "#ff4a46",
    "Proliferating PCs": "#ff4a46",
    "Inflammed secretory PCs": "#ff34ff",
    "Inflammed Secretory PCs": "#ff34ff",
    "Inflammed progenitor cells": "#ff34ff",
    "Enterocytes": "#ffff00",
    "Goblet cells": "#b15928",
    "NEUROG3+ progenitor cells": "#8a7fe0",
    "EECs": "#6651d1"
}

#ff34ff

# %%
adata = d4_lapa

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title= "Day 4 + Lapatinib")

# %%
del adata
del d4_lapa

# %%
d4_dz = sc.read_h5ad(ANALYSIS_DIR / "d4_dz_manual_labels.h5ad")

# %%
adata = d4_dz

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title= "Day 4")

# %%
del d4_dz

# %%
d2_lapa = sc.read_h5ad(ANALYSIS_DIR / "d2_lapa_manual_labels.h5ad")

# %%
adata = d2_lapa

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title= "Day 2 + Lapatinib")

# %%
d2_dz = sc.read_h5ad(ANALYSIS_DIR / "d2_dz_manual_labels.h5ad")

# %%
adata = d2_dz

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title="Day 2")

# %%
del d2_dz

# %%
g6 = sc.read_h5ad(ANALYSIS_DIR / "g6_manual_labels.h5ad")

# %%
adata = g6

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title="Day 6 Growth")

# %%
del g6

# %%
d4_as = sc.read_h5ad(ANALYSIS_DIR / "d4_as_manual_labels.h5ad")

# %%
adata = d4_as

# %%
key = "manual_label"  # the obs column you're plotting

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="manual_label", title="Day 4 + AS")

# %%
del d4_as

# %%
d10_lapa_dz_clustered = sc.read_h5ad(ANALYSIS_DIR / "d10_lapa_predictions.h5ad")

# %%
d10_lapa_dz_clustered
# Out:
# AnnData object with n_obs × n_vars = 33507 × 22
# ...

# %%
sc.pl.umap(
    d10_lapa_dz_clustered,
    color="initial_cellassign_prediction",
    frameon=False,
    ncols=1,
)

# %% [markdown]
# ### Adjust the key, to plot from the cellassign metadata for Day 10 + Lapatinib

# %%
key = "initial_cellassign_prediction"  # the obs column you're plotting

adata = d10_lapa_dz_clustered

# make sure it's categorical
adata.obs[key] = adata.obs[key].astype("category")

# assign colours in the order of the categories
adata.uns[f"{key}_colors"] = [
    celltype_palette[ct] for ct in adata.obs[key].cat.categories
]

# %%
sc.pl.umap(adata, color="initial_cellassign_prediction", title="Day 10 + Lapatinib")
